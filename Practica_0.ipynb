# %% [markdown]
# <a href="https://colab.research.google.com/github/edson-jaze/Probab/blob/main/Practica_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # probabilidad y estadistica
#
# ## unidad 1
#
# ###grupo: **2Z**
#
# ### practica 0. introduccion a python
#
# alumno: Edson Olivas Melendez
#
# docente: Dr. Jose Gabriel Rodriguez Rivas

# %%
a=12
b=25
if a > b:
  print (a, " ees mayor que", b)
else:
  print(b, 'es mayor que', a)
print(b, 'es mayor que', a)

for i in range(10):
  print(i)
  print("hola", i)
print("fuera del for")
